# %%
#-----------
# Data cleaning for test dataset
#-----------

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# use only for dictionary parsing...
import ast

import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
dataTestPlutchik = pd.read_csv('test/emotion/allcharlinepairs.csv')

# %% [markdown]
# # Check data basic info

# %%
print("Shape info: ", dataTestPlutchik.shape)
dataTestPlutchik
# Out:
# Shape info:  (51891, 9)
#                                     storyid  linenum      char  \
# 0      a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 1      a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 2      a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 3      a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 4      a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# ...                                     ...      ...       ...
# 51886  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 51887  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 51888  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
# 51889  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
# 51890  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
#
#       emotionworkerid                                            context  \
# 0                ann0                                                NaN
# 1                ann1                                                NaN
# 2                ann0  A cook was carrying an armful of oranged in th...
# 3                ann1  A cook was carrying an armful of oranged in th...
# 4                ann2  A cook was carrying an armful of oranged in th...
# ...               ...                                                ...
# 51886            ann0  Rosemary was eating a snack.|She was at a part...
# 51887            ann1  Rosemary was eating a snack.|She was at a part...
# 51888            ann0  Rosemary was eating a snack.|She was at a part...
# 51889            ann1  Rosemary was eating a snack.|She was at a part...
# 51890            ann2  Rosemary was eating a snack.|She was at a part...
#
#                                                 sentence affected  \
# 0      A cook was carrying an armful of oranged in th...      yes
# 1      A cook was carrying an armful of oranged in th...      yes
# 2               He dropped one on the floor by accident.      yes
# 3               He dropped one on the floor by accident.      yes
# 4               He dropped one on the floor by accident.      yes
# ...                                                  ...      ...
# 51886       After she stuffed herself, she regretted it.      yes
# 51887       After she stuffed herself, she regretted it.      yes
# 51888          Rosemary swore to eat healthier tomorrow.      yes
# 51889          Rosemary swore to eat healthier tomorrow.      yes
# 51890          Rosemary swore to eat healthier tomorrow.      yes
#
#                                  emotion  \
# 0                                ["joy"]
# 1                  ["useful", "nervous"]
# 2                            ["annoyed"]
# 3      ["angry at himself", "disgusted"]
# 4                         ["frustrated"]
# ...                                  ...
# 51886                          ["gross"]
# 51887                         ["regret"]
# 51888            ["to continue dieting"]
# 51889                        ["ashamed"]
# 51890                    ["COMFORTABLE"]
#
#                                                 plutchik
# 0      ["joy:3", "trust:3", "surprise:2", "anticipati...
# 1                            ["joy:2", "anticipation:2"]
# 2             ["fear:2", "surprise:2", "anticipation:2"]
# 3                               ["disgust:2", "anger:3"]
# 4                              ["surprise:2", "anger:2"]
# ...                                                  ...
# 51886                                      ["disgust:3"]
# 51887                                      ["sadness:2"]
# 51888             ["joy:2", "trust:3", "anticipation:2"]
# 51889              ["sadness:2", "disgust:2", "anger:2"]
# 51890             ["joy:3", "trust:2", "anticipation:2"]
#
# [51891 rows x 9 columns]

# %% [markdown]
# # Start modification

# %% [markdown]
# ## 1. emotion
# ### 1.1 Basic Filter

# %%
# emotion col analyze
# emotion部分的脏数据
# 0. 无效emotion
# 0.1 和sentence一致
dataTestPlutchik = dataTestPlutchik[[x.strip('[').strip(']').strip('\"').strip().replace(".", "") + "." 
                                   for x in dataTestPlutchik['emotion']] != dataTestPlutchik['sentence']]
# 0.2 like something...
dataTestPlutchik = dataTestPlutchik[~ dataTestPlutchik['emotion'].str.lower().str.contains("like")]

# 0.3 to do something...
dataTestPlutchik = dataTestPlutchik[~ dataTestPlutchik['emotion'].str.lower().str.contains("to ")]

# 1. 并列
connectorList = [" and also ", " and ", " but "]
for connector in connectorList:
    dataTestPlutchik['emotion'] = dataTestPlutchik['emotion'].str.lower().str.replace(connector, "\", \"") # 顺便统一大小写

# 2. 副词（不一定要去除其实）
decoratorList = ["very ", " a lot", " a bit", "a bit ", "little bit ", "little ", "so "]
for decorator in decoratorList:
    dataTestPlutchik['emotion'] = dataTestPlutchik['emotion'].str.replace(decorator, "")
    
# 3. 目的与原因
reasonIndentifierList = [" to", " that", " (", " about", " of", " for", " at", " in", " with", 
                         " by", " while", " on", " from", " if", " when", ":", " since"]
for reasonIndentifier in reasonIndentifierList:
    dataTestPlutchik['emotion'] = dataTestPlutchik['emotion'].str.partition("\"]")[0].str.partition(reasonIndentifier)[0]+ "\"]"
    
# 4. Special case: 省略化的从句
identityList = [" they", " he", " hes", " someone", " she", " i"]
for identity in identityList:
    dataTestPlutchik['emotion'] = dataTestPlutchik['emotion'].str.partition("\"]")[0].str.partition(identity)[0]+ "\"]"

# %%
# remove none annotator
dataTestPlutchik = dataTestPlutchik[~ (dataTestPlutchik['emotionworkerid'].str.contains("none"))]

# %%
# remove none row
noneIndicatorList = ["none", "nothing", "unsure", "n/a", "not sure", "not applicable", "no emotion"]
for noneIndicator in noneIndicatorList:
    dataTestPlutchik = dataTestPlutchik[~ (dataTestPlutchik['emotion'].str.contains(noneIndicator))]
    print("None Case deleted, current shape info update to:", dataTestPlutchik.shape)
# Out:
# None Case deleted, current shape info update to: (43248, 9)
# None Case deleted, current shape info update to: (43232, 9)
# None Case deleted, current shape info update to: (43220, 9)
# None Case deleted, current shape info update to: (43220, 9)
# None Case deleted, current shape info update to: (43220, 9)
# None Case deleted, current shape info update to: (43214, 9)
# None Case deleted, current shape info update to: (43213, 9)

# %%
# 习惯性改一下emotion和Plutchik的type, 后续好操作
dataTestPlutchik['emotion'] = [list(i.strip() for i in (x.strip('[').strip(']').strip('\"').strip().replace("\", \"", ", ")
                              .replace("\', \'", ", ").replace("\"", "").replace("`", "").replace("!", "")
                              .replace("[", "").split(', '))) for x in dataTestPlutchik['emotion']]

# %%
dataTestPlutchik['plutchik'] = [ast.literal_eval(x.replace(":", "\" : ").replace("\",", ",").replace("[", "{").replace("\"]", "}").replace("]", "}")) 
                               if "none" not in x else {} for x in dataTestPlutchik['plutchik']]

# %% [markdown]
# ### 1.2 Typo correction

# %%
import enchant
from enchant.checker import SpellChecker
#english_vocab = set(w.lower() for w in nltk.corpus.words.words())
d = enchant.Dict("en_US")

# %%
emotions = [[str1.strip("\"") for str1 in x] for x in dataTestPlutchik['emotion']]
for i in range(len(emotions)):
    for j in range(len(emotions[i])):
        word = emotions[i][j]
        word = word.strip('.').strip(';').strip(',')
        chkr = SpellChecker("en_US")
        chkr.set_text(word)
        for err in chkr:
            sug = err.suggest()[0]
            err.replace(sug)
        emotions[i][j] = chkr.get_text() #returns corrected text
    print("\r", end="")
    print("1.2 Typo correction -> Start checking, current progress: {}/{} ".format(i+1, len(emotions)), end="")
# Out:
# 1.2 Typo correction -> Start checking, current progress: 43213/43213

# %%
wrongwords = []
for lw in emotions:
    for word in lw:
        if(word.find(' ') == -1 and len(word)>0 and d.check(word)==False):
            print(lw)
            wrongwords.append(word)
wrongwords
# Out:
# []

# %%
dataTestPlutchik['emotion'] = emotions
dataTestPlutchik['emotion']
# Out:
# 0                    [joy]
# 1        [useful, nervous]
# 2                [annoyed]
# 3                  [angry]
# 4             [frustrated]
#                ...
# 51885           [famished]
# 51886              [gross]
# 51887             [regret]
# 51889            [ashamed]
# 51890        [comfortable]
# Name: emotion, Length: 43213, dtype: object

# %% [markdown]
# ### 1.3 Other explicit delete

# %%
# 特项修改 for test
dataTestPlutchik['emotion'][4514] = ['fun'] # original ['fun doing something else']
dataTestPlutchik['emotion'][10162] = ['satisfied'] # original ['fun doing something else']
dataTestPlutchik['emotion'][13415] = ['bad'] # original ['not good enough']
dataTestPlutchik['emotion'][21612] = ['happy'] # original ['glad the shop is closer']
dataTestPlutchik['emotion'][26555] = ['nervous'] # original ["nervous she'll see"]
dataTestPlutchik['emotion'][28070] = ['disappointed'] # original ['disappointed his playtime will be nerved']
dataTestPlutchik['emotion'][29702] = ['excited'] # original ['excited watch movie']
dataTestPlutchik['emotion'][30032] = ['relieved'] # original ['relieved brother is safe']  
dataTestPlutchik['emotion'][30634] = ['expecting'] # original ['expecting a positive experience']  
dataTestPlutchik['emotion'][32095] = ['relieved'] # original ['dangerous situation left']  
dataTestPlutchik['emotion'][33674] = ['disappointed'] # original ["disappointed the trick didn't work"] 
dataTestPlutchik['emotion'][37427] = ['happy'] # original ['happy there are good people']

# %%
# 杂项清除
listTotal = dataTestPlutchik['emotion']
print("curious data still...")
for index, value in listTotal.items():
    if (len(value) == 1 and value[0].count(" ") > 1):
        dataTestPlutchik = dataTestPlutchik.drop(index = index)
        print("going to remove: ", value, " @",  index)
    else:
        dataTestPlutchik['emotion'][index] = list(emotion for emotion in dataTestPlutchik['emotion'][index] if emotion.count(" ") < 1)
# Out:
# curious data still...
# going to remove:  ['as good team member']  @ 9688
# going to remove:  ['her husband should fill']  @ 13337
# going to remove:  ['well taken care']  @ 14832
# going to remove:  ['above everyone else']  @ 16874
# going to remove:  ['wanted new house']  @ 17838
# going to remove:  ['i made a good choice']  @ 17968
# going to remove:  ["he's getting an addiction"]  @ 21804
# going to remove:  ['he learned a lesson']  @ 22409
# going to remove:  ['completely let down']  @ 24346
# going to remove:  ['that his dream comes true']  @ 26618
# going to remove:  ['included as a guest']  @ 29458
# going to remove:  ['he should never drink milk']  @ 31986
# going to remove:  ['that employed are lazy']  @ 33028
# going to remove:  ["he's not assertive enough"]  @ 34849
# going to remove:  ['he just let']  @ 36139
# going to remove:  ['about secure life']  @ 43803
# going to remove:  ['his work will get easy']  @ 45003
# going to remove:  ['a bad taste']  @ 46031

# %%
# 优化 index
dataTestPlutchik = dataTestPlutchik.reset_index()
dataTestPlutchik = dataTestPlutchik.drop(labels='index',axis=1)
dataTestPlutchik.index.names = ['index']
dataTestPlutchik = dataTestPlutchik.reset_index()

# %% [markdown]
# ### 1.4 Check distribution

# %%
dataTestPlutchik
# Out:
#        index                               storyid  linenum      char  \
# 0          0  a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 1          1  a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 2          2  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 3          3  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 4          4  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# ...      ...                                   ...      ...       ...
# 43190  43190  9b53627e-41e5-47e6-9c6c-74d485572958        3  Rosemary
# 43191  43191  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 43192  43192  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 43193  43193  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
# 43194  43194  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
#
#       emotionworkerid                                            context  \
# 0                ann0                                                NaN
# 1                ann1                                                NaN
# 2                ann0  A cook was carrying an armful of oranged in th...
# 3                ann1  A cook was carrying an armful of oranged in th...
# 4                ann2  A cook was carrying an armful of oranged in th...
# ...               ...                                                ...
# 43190            ann2  Rosemary was eating a snack.|She was at a part...
# 43191            ann0  Rosemary was eating a snack.|She was at a part...
# 43192            ann1  Rosemary was eating a snack.|She was at a part...
# 43193            ann1  Rosemary was eating a snack.|She was at a part...
# 43194            ann2  Rosemary was eating a snack.|She was at a part...
#
#                                                 sentence affected  \
# 0      A cook was carrying an armful of oranged in th...      yes
# 1      A cook was carrying an armful of oranged in th...      yes
# 2               He dropped one on the floor by accident.      yes
# 3               He dropped one on the floor by accident.      yes
# 4               He dropped one on the floor by accident.      yes
# ...                                                  ...      ...
# 43190   She had been dieting for weeks and was starving.      yes
# 43191       After she stuffed herself, she regretted it.      yes
# 43192       After she stuffed herself, she regretted it.      yes
# 43193          Rosemary swore to eat healthier tomorrow.      yes
# 43194          Rosemary swore to eat healthier tomorrow.      yes
#
#                  emotion                                           plutchik
# 0                  [joy]  {'joy': 3, 'trust': 3, 'surprise': 2, 'anticip...
# 1      [useful, nervous]                      {'joy': 2, 'anticipation': 2}
# 2              [annoyed]      {'fear': 2, 'surprise': 2, 'anticipation': 2}
# 3                [angry]                         {'disgust': 2, 'anger': 3}
# 4           [frustrated]                        {'surprise': 2, 'anger': 2}
# ...                  ...                                                ...
# 43190         [famished]          {'joy': 3, 'trust': 3, 'anticipation': 3}
# 43191            [gross]                                     {'disgust': 3}
# 43192           [regret]                                     {'sadness': 2}
# 43193          [ashamed]           {'sadness': 2, 'disgust': 2, 'anger': 2}
# 43194      [comfortable]          {'joy': 3, 'trust': 2, 'anticipation': 2}
#
# [43195 rows x 10 columns]

# %%
# 看一下内容状态
# count related
# 每个emotion x 在总字典X[x]中先记录一次freq，
# 然后同case下的其它情感yi \in {[y1, ..., yn], s.t. yi != x}记录一下freq到Y[x][yi]
emotionSum = {}
for dataRow in dataTestPlutchik['emotion']:
    for emotion in dataRow:
        if emotion in emotionSum:
            relatedEmotionDict = emotionSum.get(emotion)[1];
            for relatedEmotion in dataRow:
                if relatedEmotion != emotion:
                    relatedEmotionDict[relatedEmotion] = relatedEmotionDict.get(relatedEmotion, 0) + 1
            emotionSum[emotion] = [emotionSum.get(emotion)[0]+1, relatedEmotionDict];
        else:
            emotionSum[emotion] = [1, {}];

# %%
emotionDF = pd.DataFrame(list(zip(emotionSum.keys(),[x[0] for x in emotionSum.values()], 
                                  [list(x[1].keys())[0:5] for x in emotionSum.values()],[x[1] for x in emotionSum.values()])), 
                         columns = ['emotion','freq','highly related', 'all related info'])
emotionDFTop40 = emotionDF.sort_values(by=['freq'], na_position='first', ascending=False)[0:40]

# %%
emotionDFTop40
# Out:
#           emotion  freq                                     highly related  \
# 37          happy  4833  [pleased, surprise, excitement, relieved, peac...
# 13        excited  2460     [happy, fear, anxious, cultured, appreciative]
# 17            sad  1931  [disgusted, irresponsible, angry, disappointed...
# 3         annoyed  1064  [irritated, frustrated, hungry, relieved, star...
# 100         proud  1056         [excited, accomplish, sad, anxious, tired]
# 34         scared  1013            [sad, confused, trapped, nervous, pain]
# 49   disappointed  1009            [sad, angry, upset, unhappy, satisfied]
# 4           angry   930  [sad, disappointed, unhappy, worried, embarras...
# 68       relieved   928           [happy, peaceful, safe, annoyed, guilty]
# 2         nervous   863   [afraid, embarrassed, scared, lucky, vulnerable]
# 10      surprised   736         [embarrassed, amused, elated, happy, pain]
# 90        hopeful   726   [happy, determined, alienated, curious, sadness]
# 104     satisfied   717       [contented, satiated, free, relieved, happy]
# 5      frustrated   690  [annoyed, irritated, tired, satisfied, disappo...
# 14        anxious   651            [overwhelmed, cool, fear, excited, sad]
# 44        worried   614      [angry, unhappy, uncertain, annoyed, nervous]
# 16          upset   613  [overwhelmed, afraid, miserable, disappointed,...
# 154    determined   525    [useful, anticipatory, excited, hopeful, happy]
# 22        curious   466  [hopeful, bothered, adventurous, interested, g...
# 52        content   445     [happy, carefree, satisfied, grateful, hungry]
# 56          eager   439  [responsive, enthusiastic, excitement, hopeful...
# 8     embarrassed   403      [surprised, amused, afraid, nervous, ashamed]
# 99       grateful   400      [thrilled, happy, thankful, hopeful, excited]
# 207      confused   394  [scared, trapped, scattered, embarrassed, depr...
# 57   accomplished   381   [happy, resourceful, victorious, ecstatic, busy]
# 78         guilty   318     [apprehensive, relieved, annoyed, scared, bad]
# 95        relaxed   318       [unwound, happy, calm, content, invigorated]
# 250        hungry   317        [judged, content, happy, peaceful, excited]
# 140  anticipation   317             [sad, happy, excited, afraid, hopeful]
# 220           mad   304      [disappointed, upset, frustrated, angry, sad]
# 30        shocked   293  [sad, depressed, terrified, disgusted, frustra...
# 79          tired   289   [frustrated, proud, sleepy, angry, disappointed]
# 55      disgusted   284  [sad, irresponsible, disappointed, angry, afraid]
# 38      confident   280  [renaissance, happy, proud, accomplished, steady]
# 115          calm   274       [relaxed, relief, bored, indifferent, happy]
# 85        helpful   265     [amused, concerned, caring, important, worthy]
# 0             joy   257     [happy, satisfied, anticipation, awe, excited]
# 6          amused   252  [embarrassed, surprised, helpful, awkward, angry]
# 61      concerned   249       [angry, anxious, worried, dedicated, caring]
# 175         loved   232        [arrogant, dead, unhealthy, happy, routine]
#
#                                       all related info
# 37   {'pleased': 3, 'surprise': 13, 'excitement': 1...
# 13   {'happy': 292, 'fear': 1, 'anxious': 14, 'cult...
# 17   {'disgusted': 7, 'irresponsible': 1, 'angry': ...
# 3    {'irritated': 5, 'frustrated': 19, 'hungry': 1...
# 100  {'excited': 27, 'accomplish': 1, 'sad': 3, 'an...
# 34   {'sad': 18, 'confused': 7, 'trapped': 1, 'nerv...
# 49   {'sad': 57, 'angry': 36, 'upset': 21, 'unhappy...
# 4    {'sad': 52, 'disappointed': 36, 'unhappy': 7, ...
# 68   {'happy': 58, 'peaceful': 2, 'safe': 1, 'annoy...
# 2    {'afraid': 6, 'embarrassed': 3, 'scared': 37, ...
# 10   {'embarrassed': 4, 'amused': 4, 'elated': 1, '...
# 90   {'happy': 24, 'determined': 6, 'alienated': 1,...
# 104  {'contented': 2, 'satiated': 1, 'free': 1, 're...
# 5    {'annoyed': 19, 'irritated': 1, 'tired': 3, 's...
# 14   {'overwhelmed': 2, 'cool': 2, 'fear': 2, 'exci...
# 44   {'angry': 3, 'unhappy': 4, 'uncertain': 2, 'an...
# 16   {'overwhelmed': 2, 'afraid': 2, 'miserable': 1...
# 154  {'useful': 1, 'anticipatory': 1, 'excited': 3,...
# 22   {'hopeful': 2, 'bothered': 1, 'adventurous': 1...
# 52   {'happy': 41, 'carefree': 1, 'satisfied': 10, ...
# 56   {'responsive': 1, 'enthusiastic': 3, 'exciteme...
# 8    {'surprised': 4, 'amused': 3, 'afraid': 1, 'ne...
# 99   {'thrilled': 1, 'happy': 14, 'thankful': 2, 'h...
# 207  {'scared': 7, 'trapped': 1, 'scattered': 1, 'e...
# 57   {'happy': 14, 'resourceful': 1, 'victorious': ...
# 78   {'apprehensive': 1, 'relieved': 2, 'annoyed': ...
# 95   {'unwound': 1, 'happy': 14, 'calm': 3, 'conten...
# 250  {'judged': 1, 'content': 1, 'happy': 12, 'peac...
# 140  {'sad': 2, 'happy': 15, 'excited': 4, 'afraid'...
# 220  {'disappointed': 8, 'upset': 16, 'frustrated':...
# 30   {'sad': 5, 'depressed': 1, 'terrified': 2, 'di...
# 79   {'frustrated': 3, 'proud': 1, 'sleepy': 2, 'an...
# 55   {'sad': 7, 'irresponsible': 1, 'disappointed':...
# 38   {'renaissance': 1, 'happy': 20, 'proud': 8, 'a...
# 115  {'relaxed': 3, 'relief': 1, 'bored': 1, 'indif...
# 85   {'amused': 1, 'concerned': 1, 'caring': 1, 'im...
# 0    {'happy': 9, 'satisfied': 4, 'anticipation': 1...
# 6    {'embarrassed': 3, 'surprised': 4, 'helpful': ...
# 61   {'angry': 1, 'anxious': 3, 'worried': 4, 'dedi...
# 175  {'arrogant': 1, 'dead': 1, 'unhealthy': 1, 'ha...

# %%
plt.rcParams['figure.figsize'] = (10.0, 10.0) 
plt.bar(emotionDFTop40['emotion'], emotionDFTop40['freq'])
plt.xticks(rotation=90) # 东西太多，旋转
plt.title("Emotion distribution in training")
for emotion, freq in zip(emotionDFTop40['emotion'], emotionDFTop40['freq']):
    plt.text(emotion, freq, freq, ha='center', va='bottom', fontsize=5.5)
plt.show()

# %% [markdown]
# ## 2. plutchik
# ### 2.1 Standard plutchik(including no emotion case)

# %%
for index, row in dataTestPlutchik.iterrows():
    tempalteOrder = {'joy' : 0, 'trust' : 0, 'fear' : 0, 'surprise' : 0, 'sadness' : 0, 'disgust' : 0, 'anger' : 0, 'anticipation' : 0}
    for key, value in row['plutchik'].items():
        tempalteOrder[key] = value
    dataTestPlutchik['plutchik'][index] = tempalteOrder.copy()
    print("\r", end="")
    print("2.1 Standard plutchik(including no emotion case) -> start conversion, current progress: {}/{} ".format(index+1, dataTestPlutchik.shape[0]), end="")
# Out:
# 2.1 Standard plutchik(including no emotion case) -> start conversion, current progress: 43195/43195

# %% [markdown]
# ### 2.2 Voting

# %%
mainPosIndex = pd.Series(False, index = dataTestPlutchik.index)
for index, row in dataTestPlutchik.iterrows():
    if (index == 0 or currentEditting['sentence'] != row['sentence']): # case: new sentence, update CURRENT adding
        if (index != 0):
            for key in currentEditting['plutchik']:
                # print(index - currentEditting[0], "previous: ", currentEditting[1]['plutchik'][key])
                currentEditting['plutchik'][key] //= index - currentEditting[0]
            for i in range(currentEditting['index'] + 1, index):
                for emotion in dataTestPlutchik['emotion'][i]:
                    if not emotion in dataTestPlutchik['emotion'][currentEditting['index']]:
                        dataTestPlutchik['emotion'][currentEditting['index']].append(emotion)
        currentEditting = dataTestPlutchik.iloc[index]
        mainPosIndex[currentEditting['index']] = True
    else: # case: same as previous sentence, do voting
        for key, value in dataTestPlutchik['plutchik'][index].items():
            dataTestPlutchik['plutchik'][currentEditting['index']][key] += value
    print("\r", end="")
    print("2.2 Voting -> start voting, current progress: {}/{} ".format(index+1, dataTestPlutchik.shape[0]), end="")
    
# dealing last case
for key in currentEditting['plutchik']:
    # print(index - currentEditting[0], "previous: ", currentEditting[1]['plutchik'][key])
    currentEditting['plutchik'][key] //= index - currentEditting[0]
for i in range(currentEditting['index'] + 1, index):
    for emotion in dataTestPlutchik['emotion'][i]:
        if not emotion in dataTestPlutchik['emotion'][currentEditting['index']]:
            dataTestPlutchik['emotion'][currentEditting['index']].append(emotion)
# Out:
# 2.2 Voting -> start voting, current progress: 43195/43195

# %%
dataTestPlutchik = dataTestPlutchik[mainPosIndex]
dataTestPlutchik = dataTestPlutchik.drop(labels='index',axis=1)
dataTestPlutchik = dataTestPlutchik.reset_index()
dataTestPlutchik = dataTestPlutchik.drop(labels='index',axis=1)

# %% [markdown]
# # Finish

# %%
dataTestPlutchik
# Out:
#        index                               storyid  linenum      char  \
# 0          0  a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 1          1  a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 2          2  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 3          3  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 4          4  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# ...      ...                                   ...      ...       ...
# 43190  43190  9b53627e-41e5-47e6-9c6c-74d485572958        3  Rosemary
# 43191  43191  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 43192  43192  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 43193  43193  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
# 43194  43194  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
#
#       emotionworkerid                                            context  \
# 0                ann0                                                NaN
# 1                ann1                                                NaN
# 2                ann0  A cook was carrying an armful of oranged in th...
# 3                ann1  A cook was carrying an armful of oranged in th...
# 4                ann2  A cook was carrying an armful of oranged in th...
# ...               ...                                                ...
# 43190            ann2  Rosemary was eating a snack.|She was at a part...
# 43191            ann0  Rosemary was eating a snack.|She was at a part...
# 43192            ann1  Rosemary was eating a snack.|She was at a part...
# 43193            ann1  Rosemary was eating a snack.|She was at a part...
# 43194            ann2  Rosemary was eating a snack.|She was at a part...
#
#                                                 sentence affected  \
# 0      A cook was carrying an armful of oranged in th...      yes
# 1      A cook was carrying an armful of oranged in th...      yes
# 2               He dropped one on the floor by accident.      yes
# 3               He dropped one on the floor by accident.      yes
# 4               He dropped one on the floor by accident.      yes
# ...                                                  ...      ...
# 43190   She had been dieting for weeks and was starving.      yes
# 43191       After she stuffed herself, she regretted it.      yes
# 43192       After she stuffed herself, she regretted it.      yes
# 43193          Rosemary swore to eat healthier tomorrow.      yes
# 43194          Rosemary swore to eat healthier tomorrow.      yes
#
#                  emotion                                           plutchik
# 0                  [joy]  {'joy': 3, 'trust': 3, 'fear': 0, 'surprise': ...
# 1      [useful, nervous]  {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 2              [annoyed]  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 3                [angry]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 4           [frustrated]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# ...                  ...                                                ...
# 43190         [famished]  {'joy': 3, 'trust': 3, 'fear': 0, 'surprise': ...
# 43191            [gross]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 43192           [regret]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 43193          [ashamed]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 43194      [comfortable]  {'joy': 3, 'trust': 2, 'fear': 0, 'surprise': ...
#
# [43195 rows x 10 columns]

# %%
# output
dataTestPlutchik.to_csv('test/emotion/allcharlinepairs-withDataCleaning-v1.csv')

# %%
# output - case: no emotion analyze
dataTestPlutchik.to_csv('test/emotion/allcharlinepairs-withoutDataCleaning-v1.csv')

# %%
# output - case: no plutchik analyze
dataTestPlutchik = dataTestPlutchik.drop(labels='index',axis=1)
dataTestPlutchik.to_csv('test/emotion/allcharlinepairs-withoutPlutchikVoting-v1.csv')
